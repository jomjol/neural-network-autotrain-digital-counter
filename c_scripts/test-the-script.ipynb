# %%
import sys
import os

# %%
exec(open("../configuration.py").read())

# %%
original_stdout = sys.stdout
if LogFile:
    if os.path.exists(LogFile):
        os.remove(LogFile)

# %%
if not ReportOnly:
    exec(open("script_automate/image_preparation.py").read())
# Out:
# 16 files have been deleted.
# in: ../ziffer_raw\0.0_ROI0_20211125-030625.jpg  -  out: ../ziffer_resize/0.0_ROI0_20211125-030625.jpg
# in: ../ziffer_raw\0_0_digit1_20210322-100645.jpg  -  out: ../ziffer_resize/0_0_digit1_20210322-100645.jpg
# in: ../ziffer_raw\0_0_digit7_20210406-115029.jpg  -  out: ../ziffer_resize/0_0_digit7_20210406-115029.jpg
# in: ../ziffer_raw\1_1_3.jpg  -  out: ../ziffer_resize/1_1_3.jpg
# in: ../ziffer_raw\1_1_digit5_20210527-191335.jpg  -  out: ../ziffer_resize/1_1_digit5_20210527-191335.jpg
# in: ../ziffer_raw\2_2_digit3_20210627-211437.jpg  -  out: ../ziffer_resize/2_2_digit3_20210627-211437.jpg
# in: ../ziffer_raw\2_2_digit4_20210406-110843.jpg  -  out: ../ziffer_resize/2_2_digit4_20210406-110843.jpg
# in: ../ziffer_raw\2_2_digit4_20210406-111334.jpg  -  out: ../ziffer_resize/2_2_digit4_20210406-111334.jpg
# in: ../ziffer_raw\2_2_digit4_20210413-094554(1).jpg  -  out: ../ziffer_resize/2_2_digit4_20210413-094554(1).jpg
# in: ../ziffer_raw\2_2_digit5_20210526-115910.jpg  -  out: ../ziffer_resize/2_2_digit5_20210526-115910.jpg
# in: ../ziffer_raw\2_2_digit5_20210526-120410.jpg  -  out: ../ziffer_resize/2_2_digit5_20210526-120410.jpg
# in: ../ziffer_raw\2_2_digit6_20210412-164714.jpg  -  out: ../ziffer_resize/2_2_digit6_20210412-164714.jpg
# in: ../ziffer_raw\2_2_digit7_20210406-123018.jpg  -  out: ../ziffer_resize/2_2_digit7_20210406-123018.jpg
# in: ../ziffer_raw\2_2_digit7_20210526-025315.jpg  -  out: ../ziffer_resize/2_2_digit7_20210526-025315.jpg
# in: ../ziffer_raw\2_2_digit8_20210526-105627.jpg  -  out: ../ziffer_resize/2_2_digit8_20210526-105627.jpg
# in: ../ziffer_raw\2_2_ht6_20210626-080221.jpg  -  out: ../ziffer_resize/2_2_ht6_20210626-080221.jpg

# %%
for x in configurations:
    arg1 = x
    arg2 = x
    if not ReportOnly:
#        print("Das ist in Script - Teil 1: " + str(arg1))
        a_script = open("../c_scripts/script_automate/doTraining.py").read()
        sys.argv = ["../c_scripts/script_automate/doTraining.py", arg1]
        exec(a_script)
#    print("Das ist in Script - Teil 2: " + str(arg2))
    b_script = open("../c_scripts/script_automate/doReport.py").read()
    sys.argv = ["../c_scripts/script_automate/doReport.py", arg2]
    exec(b_script)
# Out:
# dig-s0
# ../../a_output_actual/dig-s0
# Workfile does not exists - init model necessary
# Loading Model ...
# Bulilding model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 32, 20, 3)         12
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 20, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 10, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 5, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                5643
# =================================================================
# Total params: 324,631
# Trainable params: 324,625
# Non-trainable params: 6
# _________________________________________________________________
# 16
# (16, 32, 20, 3)
# (16, 11)
# (12, 32, 20, 3)
# (4, 32, 20, 3)
# 3/3 [==============================] - 1s 384ms/step - loss: 1.9985 - accuracy: 0.3750 - val_loss: 7.2588 - val_accuracy: 0.7500
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s0\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092806_dig-s0\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpmr96qf2w\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpn1snw9v5\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpn1snw9v5\assets
# ../a_output_actual/dig-s0-q.tflite
# 20211227	16	1	1.6807197332382202	7.258764266967773
# dig-s0
# File Exists
# ../ziffer_resize\0.0_ROI0_20211125-030625.jpg 0 2
# ../ziffer_resize\0_0_digit1_20210322-100645.jpg 0 2
# ../ziffer_resize\0_0_digit7_20210406-115029.jpg 0 2
# ../ziffer_resize\1_1_3.jpg 1 2
# ../ziffer_resize\1_1_digit5_20210527-191335.jpg 1 2
# dig-s1
# ../../a_output_actual/dig-s1
# Workfile does not exists - init model necessary
# Loading Model ...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 32, 20, 3)         12
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 20, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 10, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 5, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 2, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 190,487
# Trainable params: 190,481
# Non-trainable params: 6
# _________________________________________________________________
# 16
# (16, 32, 20, 3)
# (16, 11)
# (12, 32, 20, 3)
# (4, 32, 20, 3)
# 3/3 [==============================] - 1s 110ms/step - loss: 1.9889 - accuracy: 0.2708 - val_loss: 1.7943 - val_accuracy: 0.7500
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s1\assets
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s1\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092815_dig-s1\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092815_dig-s1\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmppitukims\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmppitukims\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpfsys24w3\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpfsys24w3\assets
# ../a_output_actual/dig-s1-q.tflite
# 20211227	16	1	1.7736921310424805	1.7942984104156494
# dig-s1
# File Exists
# ../ziffer_resize\0.0_ROI0_20211125-030625.jpg 0 2
# ../ziffer_resize\0_0_digit1_20210322-100645.jpg 0 2
# ../ziffer_resize\0_0_digit7_20210406-115029.jpg 0 2
# ../ziffer_resize\1_1_3.jpg 1 2
# ../ziffer_resize\1_1_digit5_20210527-191335.jpg 1 2
# dig-s2
# ../../a_output_actual/dig-s2
# Workfile does not exists - init model necessary
# Loading Model ...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_2 (Batch (None, 32, 20, 3)         12
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 20, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 10, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 10, 32)        9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 5, 32)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 4, 2, 32)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 11)                2827
# =================================================================
# Total params: 88,023
# Trainable params: 88,017
# Non-trainable params: 6
# _________________________________________________________________
# 16
# (16, 32, 20, 3)
# (16, 11)
# (12, 32, 20, 3)
# (4, 32, 20, 3)
# 3/3 [==============================] - 1s 94ms/step - loss: 2.1818 - accuracy: 0.3438 - val_loss: 5.1410 - val_accuracy: 0.7500
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s2\assets
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s2\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092822_dig-s2\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092822_dig-s2\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpwmzr5d7e\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpwmzr5d7e\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmp9qywl7m6\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmp9qywl7m6\assets
# ../a_output_actual/dig-s2-q.tflite
# 20211227	16	1	2.054295539855957	5.140954971313477
# dig-s2
# File Exists
# ../ziffer_resize\0.0_ROI0_20211125-030625.jpg 0 2
# ../ziffer_resize\0_0_digit1_20210322-100645.jpg 0 2
# ../ziffer_resize\0_0_digit7_20210406-115029.jpg 0 2
# ../ziffer_resize\1_1_3.jpg 1 2
# ../ziffer_resize\1_1_digit5_20210527-191335.jpg 1 2
# dig-s3
# ../../a_output_actual/dig-s3
# File Exists
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 32, 20, 3)         12
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 20, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 10, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 10, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 5, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 5, 32)          9248
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 2, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 11)                1419
# =================================================================
# Total params: 53,719
# Trainable params: 53,713
# Non-trainable params: 6
# _________________________________________________________________
# 16
# (16, 32, 20, 3)
# (16, 11)
# (12, 32, 20, 3)
# (4, 32, 20, 3)
# 3/3 [==============================] - 0s 87ms/step - loss: 0.8989 - accuracy: 0.7812 - val_loss: 1.6292 - val_accuracy: 0.5000
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s3\assets
# INFO:tensorflow:Assets written to: ../a_output_actual/dig-s3\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092829_dig-s3\assets
# INFO:tensorflow:Assets written to: ../b_output_historic/saved_model/20211227-092829_dig-s3\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpx_g9ps9h\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpx_g9ps9h\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpjwbgf9os\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpjwbgf9os\assets
# ../a_output_actual/dig-s3-q.tflite
# 20211227	16	1	1.021183729171753	1.629244327545166
# dig-s3
# File Exists
# ../ziffer_resize\0.0_ROI0_20211125-030625.jpg 0 2
# ../ziffer_resize\0_0_digit1_20210322-100645.jpg 0 2
# ../ziffer_resize\0_0_digit7_20210406-115029.jpg 0 2
# ../ziffer_resize\1_1_3.jpg 1 2
# ../ziffer_resize\1_1_digit5_20210527-191335.jpg 1 2

# %%
sys.stdout = original_stdout
