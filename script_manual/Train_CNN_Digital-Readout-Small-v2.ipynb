# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to classify images of a digital readout to the digits 0 to 9. Additionally a category "NaN" is introduced, to mark images that are not amibiguous.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFliteNamingAndVersion = "dig1330s2"   # Used for tflite Filename
Training_Percentage = 0.1              # 0.0 = Use all Images for Training
Epoch_Anz = 500

##########################################################################


import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import os
import numpy as np
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import History 
from tensorflow.keras.utils import to_categorical
from PIL import Image 
from pathlib import Path

loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Inside subdirectories are expected from -1, 0, 1, ... 9 in which the pictures are sorted according to their values (=category)
# * Picture size must be 20x32 with 3 color channels (RGB)
# * The filename can be arbitrary
#
# * The images are stored in the x_data[]
# * The expected category for each image in the corresponding y_data[]
#
# * The last step is a shuffle (from sklearn.utils) and split the data into training and validation data

# %%
Input_dir='../ziffer_resize'

files = glob.glob(Input_dir + '/*.jpg')
print(len(files))
x_data = []
y_data = []

for aktfile in files:
    base = os.path.basename(aktfile)
    target = base[0:1]
    if target == "N":
        category = 10                # NaN does not work --> convert to 10
    else:
        category = int(target)
    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    x_data.append(test_image)
    y_data.append(np.array([category]))

x_data = np.array(x_data)
y_data = np.array(y_data)
y_data = to_categorical(y_data, 11)
print(x_data.shape)
print(y_data.shape)

x_data, y_data = shuffle(x_data, y_data)

if (Training_Percentage > 0):
    X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
else:
    X_train = x_data
    y_train = y_data
# Out:
# 1186
# (1186, 32, 20, 3)
# (1186, 11)

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating **Conv2D** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# #### Important
# * Shape of the input layer: (32, 20, 3)
# * Number of output layers: 11
# * As loss function "categorical_crossentropy" is choosen, as it is a categories task

# %%
model = Sequential()
model.add(BatchNormalization(input_shape=(32,20,3)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), padding='same', activation="relu"))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(256,activation="relu"))
model.add(Dense(11, activation = "softmax"))

model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95), metrics = ["accuracy"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_3 (Batc  (None, 32, 20, 3)        12
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 32, 20, 32)        896
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 10, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 10, 32)        9248
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 5, 32)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 5, 32)          9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 2, 32)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 256)               65792
#
#  dense_7 (Dense)             (None, 11)                2827
#
# =================================================================
# Total params: 88,023
# Trainable params: 88,017
# Non-trainable params: 6
# _________________________________________________________________

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness, pixel shift variations and rotation angle. This is implemented with a ImageDataGenerator.

# %%
Batch_Size = 4
Shift_Range = 1
Brightness_Range = 0.2
Rotation_Angle = 5
ZoomRange = 0.3

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], 
                             height_shift_range=[-Shift_Range,Shift_Range],
                             brightness_range=[1-Brightness_Range,1+Brightness_Range],
                             zoom_range=[1-ZoomRange, 1+ZoomRange],
                             rotation_range=Rotation_Angle)

if (Training_Percentage > 0):
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    validation_iterator = datagen.flow(X_test, y_test, batch_size=Batch_Size)
    history = model.fit(train_iterator, validation_data = validation_iterator, epochs = Epoch_Anz)
else:
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    history = model.fit(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/500
# 2023-02-26 23:47:47.286255: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-02-26 23:47:47.550844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 294/297 [============================>.] - ETA: 0s - loss: 1.9246 - accuracy: 0.4267
# 2023-02-26 23:47:53.140074: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 297/297 [==============================] - 6s 17ms/step - loss: 1.9235 - accuracy: 0.4266 - val_loss: 1.5984 - val_accuracy: 0.5546
# Epoch 2/500
# 297/297 [==============================] - 4s 15ms/step - loss: 1.1633 - accuracy: 0.6223 - val_loss: 0.9641 - val_accuracy: 0.6975
# Epoch 3/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.7086 - accuracy: 0.7715 - val_loss: 0.5062 - val_accuracy: 0.8403
# Epoch 4/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.5284 - accuracy: 0.8288 - val_loss: 0.5063 - val_accuracy: 0.8824
# Epoch 5/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.4560 - accuracy: 0.8651 - val_loss: 0.5661 - val_accuracy: 0.8655
# Epoch 6/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.3843 - accuracy: 0.8853 - val_loss: 0.2578 - val_accuracy: 0.9328
# Epoch 7/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.3009 - accuracy: 0.9081 - val_loss: 0.2054 - val_accuracy: 0.9496
# Epoch 8/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.2978 - accuracy: 0.8988 - val_loss: 0.2567 - val_accuracy: 0.9412
# Epoch 9/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.2593 - accuracy: 0.9174 - val_loss: 0.2044 - val_accuracy: 0.9496
# Epoch 10/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.2642 - accuracy: 0.9148 - val_loss: 0.1007 - val_accuracy: 0.9916
# Epoch 11/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.2317 - accuracy: 0.9300 - val_loss: 0.1584 - val_accuracy: 0.9664
# Epoch 12/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1862 - accuracy: 0.9418 - val_loss: 0.1112 - val_accuracy: 0.9832
# Epoch 13/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.2287 - accuracy: 0.9283 - val_loss: 0.1478 - val_accuracy: 0.9580
# Epoch 14/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1620 - accuracy: 0.9503 - val_loss: 0.1721 - val_accuracy: 0.9328
# Epoch 15/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1791 - accuracy: 0.9393 - val_loss: 0.1424 - val_accuracy: 0.9412
# Epoch 16/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1720 - accuracy: 0.9469 - val_loss: 0.1009 - val_accuracy: 0.9664
# Epoch 17/500
# 297/297 [==============================] - 5s 15ms/step - loss: 0.1504 - accuracy: 0.9477 - val_loss: 0.1709 - val_accuracy: 0.9160
# Epoch 18/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1764 - accuracy: 0.9477 - val_loss: 0.1899 - val_accuracy: 0.9412
# Epoch 19/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1272 - accuracy: 0.9553 - val_loss: 0.1183 - val_accuracy: 0.9664
# Epoch 20/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1316 - accuracy: 0.9578 - val_loss: 0.0802 - val_accuracy: 0.9748
# Epoch 21/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1119 - accuracy: 0.9680 - val_loss: 0.1112 - val_accuracy: 0.9580
# Epoch 22/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1427 - accuracy: 0.9570 - val_loss: 0.1047 - val_accuracy: 0.9664
# Epoch 23/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1303 - accuracy: 0.9612 - val_loss: 0.0813 - val_accuracy: 0.9832
# Epoch 24/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1093 - accuracy: 0.9637 - val_loss: 0.0497 - val_accuracy: 0.9832
# Epoch 25/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0893 - accuracy: 0.9705 - val_loss: 0.0502 - val_accuracy: 0.9832
# Epoch 26/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1005 - accuracy: 0.9680 - val_loss: 0.1537 - val_accuracy: 0.9664
# Epoch 27/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1330 - accuracy: 0.9595 - val_loss: 0.0391 - val_accuracy: 0.9916
# Epoch 28/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1038 - accuracy: 0.9680 - val_loss: 0.0800 - val_accuracy: 0.9664
# Epoch 29/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0710 - accuracy: 0.9806 - val_loss: 0.0721 - val_accuracy: 0.9664
# Epoch 30/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0985 - accuracy: 0.9705 - val_loss: 0.0223 - val_accuracy: 0.9916
# Epoch 31/500
# 297/297 [==============================] - 5s 16ms/step - loss: 0.1296 - accuracy: 0.9629 - val_loss: 0.0867 - val_accuracy: 0.9748
# Epoch 32/500
# 297/297 [==============================] - 5s 16ms/step - loss: 0.0788 - accuracy: 0.9815 - val_loss: 0.1048 - val_accuracy: 0.9664
# Epoch 33/500
# 297/297 [==============================] - 5s 15ms/step - loss: 0.0785 - accuracy: 0.9739 - val_loss: 0.0476 - val_accuracy: 0.9832
# Epoch 34/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1121 - accuracy: 0.9646 - val_loss: 0.0278 - val_accuracy: 0.9916
# Epoch 35/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0942 - accuracy: 0.9730 - val_loss: 0.1465 - val_accuracy: 0.9496
# Epoch 36/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0907 - accuracy: 0.9722 - val_loss: 0.0161 - val_accuracy: 0.9916
# Epoch 37/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0976 - accuracy: 0.9705 - val_loss: 0.0451 - val_accuracy: 0.9832
# Epoch 38/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0624 - accuracy: 0.9798 - val_loss: 0.0768 - val_accuracy: 0.9832
# Epoch 39/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0612 - accuracy: 0.9806 - val_loss: 0.0719 - val_accuracy: 0.9664
# Epoch 40/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.1037 - accuracy: 0.9688 - val_loss: 0.1422 - val_accuracy: 0.9580
# Epoch 41/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0587 - accuracy: 0.9815 - val_loss: 0.0415 - val_accuracy: 0.9832
# Epoch 42/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0701 - accuracy: 0.9806 - val_loss: 0.0318 - val_accuracy: 0.9832
# Epoch 43/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0805 - accuracy: 0.9747 - val_loss: 0.0926 - val_accuracy: 0.9832
# Epoch 44/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0813 - accuracy: 0.9772 - val_loss: 0.0214 - val_accuracy: 1.0000
# Epoch 45/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0628 - accuracy: 0.9806 - val_loss: 0.0191 - val_accuracy: 0.9916
# Epoch 46/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0734 - accuracy: 0.9781 - val_loss: 0.1282 - val_accuracy: 0.9664
# Epoch 47/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0507 - accuracy: 0.9857 - val_loss: 0.0535 - val_accuracy: 0.9748
# Epoch 48/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0773 - accuracy: 0.9781 - val_loss: 0.1156 - val_accuracy: 0.9748
# Epoch 49/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.1010 - accuracy: 0.9772 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 50/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0802 - accuracy: 0.9798 - val_loss: 0.1494 - val_accuracy: 0.9664
# Epoch 51/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0687 - accuracy: 0.9772 - val_loss: 0.0898 - val_accuracy: 0.9748
# Epoch 52/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0644 - accuracy: 0.9798 - val_loss: 0.0442 - val_accuracy: 0.9748
# Epoch 53/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0590 - accuracy: 0.9823 - val_loss: 0.0333 - val_accuracy: 0.9916
# Epoch 54/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0686 - accuracy: 0.9772 - val_loss: 0.0625 - val_accuracy: 0.9664
# Epoch 55/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0717 - accuracy: 0.9848 - val_loss: 0.0819 - val_accuracy: 0.9916
# Epoch 56/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0683 - accuracy: 0.9831 - val_loss: 0.0981 - val_accuracy: 0.9748
# Epoch 57/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0751 - accuracy: 0.9789 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 58/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0693 - accuracy: 0.9772 - val_loss: 0.0564 - val_accuracy: 0.9832
# Epoch 59/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0677 - accuracy: 0.9823 - val_loss: 0.0247 - val_accuracy: 0.9916
# Epoch 60/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0779 - accuracy: 0.9806 - val_loss: 0.0227 - val_accuracy: 0.9916
# Epoch 61/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0460 - accuracy: 0.9806 - val_loss: 0.0397 - val_accuracy: 0.9832
# Epoch 62/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0839 - accuracy: 0.9815 - val_loss: 0.0751 - val_accuracy: 0.9832
# Epoch 63/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0676 - accuracy: 0.9789 - val_loss: 0.0367 - val_accuracy: 0.9916
# Epoch 64/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 65/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0281 - accuracy: 0.9924 - val_loss: 0.0904 - val_accuracy: 0.9748
# Epoch 66/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0674 - accuracy: 0.9857 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 67/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0532 - accuracy: 0.9806 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 68/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0783 - accuracy: 0.9781 - val_loss: 0.0394 - val_accuracy: 0.9916
# Epoch 69/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0294 - accuracy: 0.9890 - val_loss: 0.1114 - val_accuracy: 0.9748
# Epoch 70/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0677 - accuracy: 0.9831 - val_loss: 0.2552 - val_accuracy: 0.9664
# Epoch 71/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0516 - accuracy: 0.9840 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 72/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0494 - accuracy: 0.9865 - val_loss: 0.0240 - val_accuracy: 0.9916
# Epoch 73/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0430 - accuracy: 0.9882 - val_loss: 0.1016 - val_accuracy: 0.9832
# Epoch 74/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0655 - accuracy: 0.9798 - val_loss: 0.0442 - val_accuracy: 0.9748
# Epoch 75/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0422 - accuracy: 0.9874 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 76/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0528 - accuracy: 0.9924 - val_loss: 0.0254 - val_accuracy: 0.9916
# Epoch 77/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0383 - accuracy: 0.9874 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 78/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0580 - accuracy: 0.9874 - val_loss: 0.0892 - val_accuracy: 0.9748
# Epoch 79/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0555 - accuracy: 0.9865 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 80/500
# 297/297 [==============================] - 5s 15ms/step - loss: 0.0439 - accuracy: 0.9882 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 81/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0393 - accuracy: 0.9899 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 82/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0413 - accuracy: 0.9907 - val_loss: 0.1129 - val_accuracy: 0.9664
# Epoch 83/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0562 - accuracy: 0.9865 - val_loss: 0.0393 - val_accuracy: 0.9916
# Epoch 84/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0324 - accuracy: 0.9882 - val_loss: 0.0373 - val_accuracy: 0.9916
# Epoch 85/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0362 - accuracy: 0.9899 - val_loss: 0.0145 - val_accuracy: 0.9916
# Epoch 86/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0429 - accuracy: 0.9874 - val_loss: 0.0165 - val_accuracy: 0.9916
# Epoch 87/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0647 - accuracy: 0.9815 - val_loss: 0.0595 - val_accuracy: 0.9748
# Epoch 88/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0468 - accuracy: 0.9899 - val_loss: 0.0098 - val_accuracy: 0.9916
# Epoch 89/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0393 - accuracy: 0.9907 - val_loss: 0.1373 - val_accuracy: 0.9748
# Epoch 90/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0397 - accuracy: 0.9899 - val_loss: 0.0530 - val_accuracy: 0.9748
# Epoch 91/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0362 - accuracy: 0.9916 - val_loss: 0.0150 - val_accuracy: 0.9916
# Epoch 92/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0365 - accuracy: 0.9949 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 93/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0392 - accuracy: 0.9840 - val_loss: 0.0787 - val_accuracy: 0.9748
# Epoch 94/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.0308 - val_accuracy: 0.9832
# Epoch 95/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0471 - accuracy: 0.9848 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 96/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0500 - accuracy: 0.9831 - val_loss: 0.0480 - val_accuracy: 0.9916
# Epoch 97/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0263 - accuracy: 0.9933 - val_loss: 0.0176 - val_accuracy: 0.9916
# Epoch 98/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0280 - accuracy: 0.9933 - val_loss: 0.0105 - val_accuracy: 0.9916
# Epoch 99/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0281 - accuracy: 0.9916 - val_loss: 0.0242 - val_accuracy: 0.9916
# Epoch 100/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0540 - accuracy: 0.9857 - val_loss: 0.0484 - val_accuracy: 0.9916
# Epoch 101/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0226 - accuracy: 0.9916 - val_loss: 0.0330 - val_accuracy: 0.9832
# Epoch 102/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 103/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0236 - accuracy: 0.9933 - val_loss: 0.0322 - val_accuracy: 0.9832
# Epoch 104/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0654 - accuracy: 0.9806 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 105/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0189 - accuracy: 0.9916 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 106/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0297 - accuracy: 0.9924 - val_loss: 0.0211 - val_accuracy: 0.9916
# Epoch 107/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0338 - accuracy: 0.9941 - val_loss: 0.0721 - val_accuracy: 0.9916
# Epoch 108/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0563 - accuracy: 0.9899 - val_loss: 0.0121 - val_accuracy: 0.9916
# Epoch 109/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0228 - accuracy: 0.9924 - val_loss: 2.8855e-04 - val_accuracy: 1.0000
# Epoch 110/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0221 - accuracy: 0.9924 - val_loss: 0.0700 - val_accuracy: 0.9916
# Epoch 111/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0535 - accuracy: 0.9899 - val_loss: 0.0089 - val_accuracy: 0.9916
# Epoch 112/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0281 - accuracy: 0.9941 - val_loss: 0.0476 - val_accuracy: 0.9916
# Epoch 113/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 114/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0512 - accuracy: 0.9874 - val_loss: 0.0937 - val_accuracy: 0.9832
# Epoch 115/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0601 - accuracy: 0.9806 - val_loss: 0.0123 - val_accuracy: 0.9916
# Epoch 116/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0382 - accuracy: 0.9907 - val_loss: 0.0149 - val_accuracy: 0.9916
# Epoch 117/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0565 - accuracy: 0.9890 - val_loss: 0.0473 - val_accuracy: 0.9832
# Epoch 118/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0669 - accuracy: 0.9831 - val_loss: 0.0448 - val_accuracy: 0.9748
# Epoch 119/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 120/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0291 - accuracy: 0.9916 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 121/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0442 - accuracy: 0.9865 - val_loss: 0.1044 - val_accuracy: 0.9916
# Epoch 122/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0550 - accuracy: 0.9848 - val_loss: 0.0211 - val_accuracy: 0.9916
# Epoch 123/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0216 - accuracy: 0.9916 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 124/500
# 297/297 [==============================] - 5s 15ms/step - loss: 0.0392 - accuracy: 0.9874 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 125/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0410 - accuracy: 0.9899 - val_loss: 0.0238 - val_accuracy: 0.9916
# Epoch 126/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0297 - accuracy: 0.9907 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 127/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0366 - accuracy: 0.9874 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 128/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0234 - accuracy: 0.9941 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 129/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0272 - accuracy: 0.9949 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 130/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0237 - accuracy: 0.9958 - val_loss: 0.0173 - val_accuracy: 0.9916
# Epoch 131/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0530 - accuracy: 0.9865 - val_loss: 0.0324 - val_accuracy: 0.9916
# Epoch 132/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0318 - accuracy: 0.9949 - val_loss: 2.2581e-04 - val_accuracy: 1.0000
# Epoch 133/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0257 - accuracy: 0.9890 - val_loss: 7.2374e-04 - val_accuracy: 1.0000
# Epoch 134/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.0659 - val_accuracy: 0.9916
# Epoch 135/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0228 - accuracy: 0.9933 - val_loss: 0.0063 - val_accuracy: 0.9916
# Epoch 136/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0324 - accuracy: 0.9874 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 137/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 138/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0336 - val_accuracy: 0.9916
# Epoch 139/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0623 - accuracy: 0.9865 - val_loss: 0.0361 - val_accuracy: 0.9832
# Epoch 140/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0280 - accuracy: 0.9941 - val_loss: 0.0097 - val_accuracy: 0.9916
# Epoch 141/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 3.7773e-04 - val_accuracy: 1.0000
# Epoch 142/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0350 - accuracy: 0.9899 - val_loss: 0.1516 - val_accuracy: 0.9916
# Epoch 143/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0210 - accuracy: 0.9949 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 144/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0238 - val_accuracy: 0.9916
# Epoch 145/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0495 - accuracy: 0.9907 - val_loss: 0.0116 - val_accuracy: 0.9916
# Epoch 146/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0128 - accuracy: 0.9941 - val_loss: 0.0125 - val_accuracy: 0.9916
# Epoch 147/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0298 - accuracy: 0.9933 - val_loss: 1.9737e-04 - val_accuracy: 1.0000
# Epoch 148/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0205 - accuracy: 0.9949 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 149/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0208 - accuracy: 0.9958 - val_loss: 1.6804e-04 - val_accuracy: 1.0000
# Epoch 150/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0124 - val_accuracy: 0.9916
# Epoch 151/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0347 - accuracy: 0.9933 - val_loss: 0.2239 - val_accuracy: 0.9748
# Epoch 152/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.0146 - val_accuracy: 0.9916
# Epoch 153/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0642 - accuracy: 0.9874 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 154/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0192 - accuracy: 0.9958 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 155/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0281 - accuracy: 0.9907 - val_loss: 0.0328 - val_accuracy: 0.9832
# Epoch 156/500
# 297/297 [==============================] - 5s 16ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 157/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 158/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0369 - accuracy: 0.9916 - val_loss: 7.5292e-04 - val_accuracy: 1.0000
# Epoch 159/500
# 297/297 [==============================] - 5s 16ms/step - loss: 0.0342 - accuracy: 0.9899 - val_loss: 0.0810 - val_accuracy: 0.9916
# Epoch 160/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0243 - accuracy: 0.9924 - val_loss: 2.1141e-04 - val_accuracy: 1.0000
# Epoch 161/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.0439 - val_accuracy: 0.9916
# Epoch 162/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 163/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 164/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0366 - accuracy: 0.9924 - val_loss: 0.0062 - val_accuracy: 0.9916
# Epoch 165/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0199 - accuracy: 0.9924 - val_loss: 0.0601 - val_accuracy: 0.9916
# Epoch 166/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0336 - accuracy: 0.9924 - val_loss: 0.0773 - val_accuracy: 0.9832
# Epoch 167/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0430 - accuracy: 0.9933 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 168/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0289 - accuracy: 0.9890 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 169/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0159 - accuracy: 0.9941 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 170/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0225 - accuracy: 0.9958 - val_loss: 0.0321 - val_accuracy: 0.9832
# Epoch 171/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0209 - accuracy: 0.9941 - val_loss: 0.0796 - val_accuracy: 0.9832
# Epoch 172/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 173/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 174/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 175/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0237 - accuracy: 0.9941 - val_loss: 0.0123 - val_accuracy: 0.9916
# Epoch 176/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0269 - accuracy: 0.9924 - val_loss: 0.0853 - val_accuracy: 0.9916
# Epoch 177/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0075 - val_accuracy: 0.9916
# Epoch 178/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0157 - accuracy: 0.9941 - val_loss: 0.0391 - val_accuracy: 0.9916
# Epoch 179/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0205 - accuracy: 0.9941 - val_loss: 9.6197e-04 - val_accuracy: 1.0000
# Epoch 180/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0381 - accuracy: 0.9916 - val_loss: 0.0157 - val_accuracy: 0.9832
# Epoch 181/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 7.0413e-04 - val_accuracy: 1.0000
# Epoch 182/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0242 - accuracy: 0.9949 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 183/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0337 - accuracy: 0.9907 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 184/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0137 - accuracy: 0.9941 - val_loss: 0.0227 - val_accuracy: 0.9916
# Epoch 185/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0197 - accuracy: 0.9949 - val_loss: 4.3867e-05 - val_accuracy: 1.0000
# Epoch 186/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0319 - accuracy: 0.9890 - val_loss: 7.9942e-05 - val_accuracy: 1.0000
# Epoch 187/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0314 - accuracy: 0.9941 - val_loss: 3.8066e-04 - val_accuracy: 1.0000
# Epoch 188/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0261 - accuracy: 0.9916 - val_loss: 4.2325e-04 - val_accuracy: 1.0000
# Epoch 189/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0391 - accuracy: 0.9916 - val_loss: 0.0504 - val_accuracy: 0.9832
# Epoch 190/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.0587 - val_accuracy: 0.9832
# Epoch 191/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0172 - accuracy: 0.9966 - val_loss: 0.1257 - val_accuracy: 0.9664
# Epoch 192/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0243 - accuracy: 0.9941 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 193/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0321 - accuracy: 0.9916 - val_loss: 0.0095 - val_accuracy: 0.9916
# Epoch 194/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0309 - accuracy: 0.9941 - val_loss: 4.6744e-04 - val_accuracy: 1.0000
# Epoch 195/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0140 - val_accuracy: 0.9916
# Epoch 196/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0161 - val_accuracy: 0.9916
# Epoch 197/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0297 - accuracy: 0.9949 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 198/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0186 - accuracy: 0.9966 - val_loss: 2.4535e-04 - val_accuracy: 1.0000
# Epoch 199/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0474 - accuracy: 0.9865 - val_loss: 0.0150 - val_accuracy: 0.9916
# Epoch 200/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0255 - accuracy: 0.9899 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 201/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0459 - accuracy: 0.9958 - val_loss: 2.0436e-04 - val_accuracy: 1.0000
# Epoch 202/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0119 - accuracy: 0.9958 - val_loss: 8.5192e-04 - val_accuracy: 1.0000
# Epoch 203/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0239 - accuracy: 0.9933 - val_loss: 0.0419 - val_accuracy: 0.9916
# Epoch 204/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.0434 - val_accuracy: 0.9916
# Epoch 205/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0295 - accuracy: 0.9949 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 206/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0355 - accuracy: 0.9907 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 207/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 0.0720 - val_accuracy: 0.9916
# Epoch 208/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0457 - accuracy: 0.9916 - val_loss: 0.0274 - val_accuracy: 0.9916
# Epoch 209/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0780 - val_accuracy: 0.9832
# Epoch 210/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0408 - accuracy: 0.9899 - val_loss: 5.1730e-04 - val_accuracy: 1.0000
# Epoch 211/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0196 - accuracy: 0.9949 - val_loss: 0.0141 - val_accuracy: 0.9916
# Epoch 212/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0191 - accuracy: 0.9924 - val_loss: 8.3050e-05 - val_accuracy: 1.0000
# Epoch 213/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0348 - accuracy: 0.9924 - val_loss: 0.0174 - val_accuracy: 0.9916
# Epoch 214/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0194 - accuracy: 0.9949 - val_loss: 0.1396 - val_accuracy: 0.9916
# Epoch 215/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0234 - accuracy: 0.9933 - val_loss: 4.0776e-04 - val_accuracy: 1.0000
# Epoch 216/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0101 - accuracy: 0.9975 - val_loss: 3.8042e-04 - val_accuracy: 1.0000
# Epoch 217/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0063 - accuracy: 0.9975 - val_loss: 0.0221 - val_accuracy: 0.9916
# Epoch 218/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0546 - accuracy: 0.9941 - val_loss: 2.5703e-04 - val_accuracy: 1.0000
# Epoch 219/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0300 - accuracy: 0.9907 - val_loss: 0.0508 - val_accuracy: 0.9916
# Epoch 220/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 1.8695e-04 - val_accuracy: 1.0000
# Epoch 221/500
# 297/297 [==============================] - 168s 567ms/step - loss: 0.0192 - accuracy: 0.9949 - val_loss: 0.0737 - val_accuracy: 0.9916
# Epoch 222/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0118 - val_accuracy: 0.9916
# Epoch 223/500
# 297/297 [==============================] - 188s 635ms/step - loss: 0.0247 - accuracy: 0.9924 - val_loss: 0.0100 - val_accuracy: 0.9916
# Epoch 224/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0313 - accuracy: 0.9907 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 225/500
# 297/297 [==============================] - 6s 19ms/step - loss: 0.0316 - accuracy: 0.9907 - val_loss: 0.0291 - val_accuracy: 0.9916
# Epoch 226/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.0095 - val_accuracy: 0.9916
# Epoch 227/500
# 297/297 [==============================] - 934s 3s/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 0.0215 - val_accuracy: 0.9916
# Epoch 228/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 2.4421e-04 - val_accuracy: 1.0000
# Epoch 229/500
# 297/297 [==============================] - 1021s 3s/step - loss: 0.0322 - accuracy: 0.9941 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch
500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 9.7645e-04 - val_accuracy: 1.0000
# Epoch 429/500
# 297/297 [==============================] - 5s 16ms/step - loss: 0.0156 - accuracy: 0.9975 - val_loss: 0.2065 - val_accuracy: 0.9832
# Epoch 430/500
# 297/297 [==============================] - 6s 19ms/step - loss: 0.0255 - accuracy: 0.9958 - val_loss: 6.3412e-05 - val_accuracy: 1.0000
# Epoch 431/500
# 297/297 [==============================] - 6s 20ms/step - loss: 0.0342 - accuracy: 0.9916 - val_loss: 2.8008e-04 - val_accuracy: 1.0000
# Epoch 432/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0044 - accuracy: 0.9975 - val_loss: 0.1513 - val_accuracy: 0.9916
# Epoch 433/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0058 - accuracy: 0.9966 - val_loss: 0.0306 - val_accuracy: 0.9916
# Epoch 434/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0262 - accuracy: 0.9958 - val_loss: 1.9967e-04 - val_accuracy: 1.0000
# Epoch 435/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0155 - accuracy: 0.9975 - val_loss: 2.3897e-05 - val_accuracy: 1.0000
# Epoch 436/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0320 - accuracy: 0.9958 - val_loss: 2.6067e-05 - val_accuracy: 1.0000
# Epoch 437/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 438/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.0603 - val_accuracy: 0.9916
# Epoch 439/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0833 - val_accuracy: 0.9832
# Epoch 440/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0255 - accuracy: 0.9958 - val_loss: 0.0499 - val_accuracy: 0.9916
# Epoch 441/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0128 - val_accuracy: 0.9916
# Epoch 442/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0255 - accuracy: 0.9941 - val_loss: 3.6194e-04 - val_accuracy: 1.0000
# Epoch 443/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 3.1198e-06 - val_accuracy: 1.0000
# Epoch 444/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0103 - accuracy: 0.9975 - val_loss: 3.1024e-06 - val_accuracy: 1.0000
# Epoch 445/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 7.9605e-04 - val_accuracy: 1.0000
# Epoch 446/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0013 - accuracy: 0.9992 - val_loss: 3.2871e-06 - val_accuracy: 1.0000
# Epoch 447/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0229 - accuracy: 0.9966 - val_loss: 1.6972e-05 - val_accuracy: 1.0000
# Epoch 448/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 5.5333e-05 - val_accuracy: 1.0000
# Epoch 449/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0207 - accuracy: 0.9983 - val_loss: 2.3284e-05 - val_accuracy: 1.0000
# Epoch 450/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0139 - accuracy: 0.9949 - val_loss: 6.4923e-07 - val_accuracy: 1.0000
# Epoch 451/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0116 - accuracy: 0.9983 - val_loss: 1.0732e-04 - val_accuracy: 1.0000
# Epoch 452/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 2.3015e-04 - val_accuracy: 1.0000
# Epoch 453/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0238 - accuracy: 0.9949 - val_loss: 2.0423e-05 - val_accuracy: 1.0000
# Epoch 454/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 2.7775e-07 - val_accuracy: 1.0000
# Epoch 455/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0113 - accuracy: 0.9992 - val_loss: 6.1280e-04 - val_accuracy: 1.0000
# Epoch 456/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.0127 - val_accuracy: 0.9916
# Epoch 457/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0328 - accuracy: 0.9949 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 458/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0016 - accuracy: 0.9992 - val_loss: 0.0097 - val_accuracy: 0.9916
# Epoch 459/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 1.9140e-05 - val_accuracy: 1.0000
# Epoch 460/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0053 - accuracy: 0.9975 - val_loss: 1.6123e-06 - val_accuracy: 1.0000
# Epoch 461/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0210 - accuracy: 0.9966 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 462/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 4.4717e-06 - val_accuracy: 1.0000
# Epoch 463/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 9.7773e-04 - val_accuracy: 1.0000
# Epoch 464/500
# 297/297 [==============================] - 930s 3s/step - loss: 0.0209 - accuracy: 0.9966 - val_loss: 1.0770e-05 - val_accuracy: 1.0000
# Epoch 465/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0025 - accuracy: 0.9983 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 466/500
# 297/297 [==============================] - 945s 3s/step - loss: 5.4130e-04 - accuracy: 1.0000 - val_loss: 2.8895e-04 - val_accuracy: 1.0000
# Epoch 467/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0275 - accuracy: 0.9966 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 468/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0064 - accuracy: 0.9975 - val_loss: 3.9857e-05 - val_accuracy: 1.0000
# Epoch 469/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0284 - accuracy: 0.9949 - val_loss: 1.2846e-07 - val_accuracy: 1.0000
# Epoch 470/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0048 - accuracy: 0.9992 - val_loss: 1.6051e-05 - val_accuracy: 1.0000
# Epoch 471/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0226 - accuracy: 0.9975 - val_loss: 1.8093e-05 - val_accuracy: 1.0000
# Epoch 472/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 473/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0988 - val_accuracy: 0.9916
# Epoch 474/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0298 - accuracy: 0.9958 - val_loss: 2.3560e-05 - val_accuracy: 1.0000
# Epoch 475/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0011 - accuracy: 0.9992 - val_loss: 1.5012e-05 - val_accuracy: 1.0000
# Epoch 476/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0099 - accuracy: 0.9975 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 477/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 5.4736e-05 - val_accuracy: 1.0000
# Epoch 478/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 1.9442e-08 - val_accuracy: 1.0000
# Epoch 479/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 8.2906e-04 - val_accuracy: 1.0000
# Epoch 480/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0176 - accuracy: 0.9966 - val_loss: 0.0196 - val_accuracy: 0.9916
# Epoch 481/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0165 - accuracy: 0.9975 - val_loss: 2.4262e-04 - val_accuracy: 1.0000
# Epoch 482/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0120 - accuracy: 0.9949 - val_loss: 0.0971 - val_accuracy: 0.9916
# Epoch 483/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0298 - accuracy: 0.9966 - val_loss: 0.0102 - val_accuracy: 0.9916
# Epoch 484/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0397 - accuracy: 0.9949 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 485/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0161 - accuracy: 0.9983 - val_loss: 7.6846e-06 - val_accuracy: 1.0000
# Epoch 486/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0119 - accuracy: 0.9975 - val_loss: 4.3745e-08 - val_accuracy: 1.0000
# Epoch 487/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 2.1358e-04 - val_accuracy: 1.0000
# Epoch 488/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0165 - val_accuracy: 0.9916
# Epoch 489/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0082 - accuracy: 0.9983 - val_loss: 1.9205e-04 - val_accuracy: 1.0000
# Epoch 490/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0246 - accuracy: 0.9958 - val_loss: 8.8185e-08 - val_accuracy: 1.0000
# Epoch 491/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 2.1409e-05 - val_accuracy: 1.0000
# Epoch 492/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0110 - accuracy: 0.9983 - val_loss: 0.1020 - val_accuracy: 0.9916
# Epoch 493/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 1.9887e-06 - val_accuracy: 1.0000
# Epoch 494/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0379 - val_accuracy: 0.9916
# Epoch 495/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.0615 - val_accuracy: 0.9916
# Epoch 496/500
# 297/297 [==============================] - 4s 15ms/step - loss: 0.0092 - accuracy: 0.9975 - val_loss: 4.3231e-04 - val_accuracy: 1.0000
# Epoch 497/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.1282 - val_accuracy: 0.9916
# Epoch 498/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0083 - accuracy: 0.9992 - val_loss: 7.1589e-07 - val_accuracy: 1.0000
# Epoch 499/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0274 - accuracy: 0.9958 - val_loss: 3.3971e-04 - val_accuracy: 1.0000
# Epoch 500/500
# 297/297 [==============================] - 4s 14ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0714 - val_accuracy: 0.9916

# %% [markdown]
# ### Learing result
#
# * Visualization of the training and validation results

# %%
loss_ges = np.append(loss_ges, history.history['loss'])
plt.semilogy(history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by hand
#
# * The following code uses the trained model to check the deviation for each picture.
# * x-axis walks through each pixel, y-axis shows the result

# %% [markdown]
# ### Check each image for expected and deviation
# * setting the switch "only_deviation = true" will only print the images for which the classification and the CNN-result deviates
#
# The output contains the following information:
#
# | Filename      | Expected Category           | Predicted Category        |
# |------------- |:-----------------------------:|--------------|
# | ziffer_sortiert_resize_NaN/5\Ziffer_4_0034.jpg | 4  | -1 |

# %%
Input_dir='ziffer_sortiert_resize'
res = []
only_deviation = True
show_wrong_image = True

files = glob.glob(Input_dir + '/*.jpg')

for aktfile in files:
    base = os.path.basename(aktfile)
    target = base[0:1]
    if target == "N":
        zw1 = -1
    else:
        zw1 = int(target)
    expected_class = zw1
    image_in = Image.open(aktfile)
    test_image = np.array(image_in, dtype="float32")
    img = np.reshape(test_image,[1,32,20,3])
    classes = np.argmax(model.predict(img), axis=-1)
    classes = classes[0]
    if classes == 10: 
        classes = -1
    zw2 = classes
    zw3 = zw2 - zw1
    res.append(np.array([zw1, zw2, zw3]))
    if only_deviation == True:
        if str(classes) != str(expected_class):
            print(aktfile + " " + str(expected_class) +  " " + str(classes))
            if show_wrong_image == True:
                display(image_in)
    else:
        print(aktfile + " " + aktsubdir +  " " + str(classes))
        

res = np.asarray(res)


plt.plot(res[:,0])
plt.plot(res[:,1])
plt.title('Result')
plt.ylabel('Digital Value')
plt.xlabel('#Picture')
plt.legend(['real','model'], loc='upper left')
plt.show()

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "h5" file format

# %%
FileName = TFliteNamingAndVersion

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)

# %%
FileName = TFliteNamingAndVersion + "q.tflite"

import tensorflow as tf

def representative_dataset():
    for n in range(x_data[0].size):
      data = np.expand_dims(x_data[5], axis=0)
      yield [data.astype(np.float32)]
        
converter2 = tf.lite.TFLiteConverter.from_keras_model(model)
converter2.representative_dataset = representative_dataset
converter2.optimizations = [tf.lite.Optimize.DEFAULT]
converter2.representative_dataset = representative_dataset
tflite_quant_model = converter2.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size

# %% [markdown]
# Checking the images shows, that this are border line images, which can be interpreted as a good digit or a faulty one.
