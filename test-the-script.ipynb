# %%
import sys
import os

# %%
exec(open("configuration.py").read())

# %%
original_stdout = sys.stdout
if LogFile:
    if os.path.exists(LogFile):
        os.remove(LogFile)

# %%
if not ReportOnly:
    exec(open("script_automate/image_preparation.py").read())
# Out:
# INFO:tensorflow:Assets written to: saved_model/dig-s0\assets
# INFO:tensorflow:Assets written to: saved_model/20211224-125700_dig-s0\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpxtbed_d5\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmptmgphtxd\assets
# INFO:tensorflow:Assets written to: saved_model/dig-s1\assets
# INFO:tensorflow:Assets written to: saved_model/20211224-125808_dig-s1\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpwndhhq9e\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpb84vh9nj\assets

# %%
for x in configurations:
    arg1 = x
    arg2 = x
    if not ReportOnly:
        print("Das ist in Script - Teil 1: " + str(arg1))
        a_script = open("script_automate/doTraining.py").read()
        sys.argv = ["script_automate/doTraining.py", arg1]
        exec(a_script)
    print("Das ist in Script - Teil 2: " + str(arg2))
    b_script = open("script_automate/doReport.py").read()
    sys.argv = ["script_automate/doReport.py", arg2]
    exec(b_script)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmptmgphtxd\assets
# INFO:tensorflow:Assets written to: saved_model/dig-s1\assets
# INFO:tensorflow:Assets written to: saved_model/20211224-125808_dig-s1\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpwndhhq9e\assets
# INFO:tensorflow:Assets written to: C:\Users\Muell\AppData\Local\Temp\tmpb84vh9nj\assets

# %%
sys.stdout = original_stdout
